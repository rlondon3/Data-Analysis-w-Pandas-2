# %% [markdown]
# #### THE POLICE DATASET

# %% [markdown]
#  #### Here, the cars Dataset is a vehicle data set with make, model information and driving features. It is about the types of vehicles from different countries.
#  #### It records Drivetrain, MSRP, Invoice, EngineSize, Cylinders, Horsepower, MPG_CIty, MPG_Highway, Weight, Wheelbase, and length.
#
#  #### This data is available as a CSV file. An analysis of this data will be preformed using the Pandas DataFrame.

# %%
import pandas as pd

# %%
data = pd.read_csv(r"./cars_data.csv")

# %%
data
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
data.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0

# %% [markdown]
# ## Display unique MGP_Highway values for the vehicles

# %%
data.nunique()
# Out:
# Make            38
# Model          425
# Type             6
# Origin           3
# DriveTrain       3
# MSRP           410
# Invoice        425
# EngineSize      43
# Cylinders        7
# Horsepower     110
# MPG_City        28
# MPG_Highway     33
# Weight         348
# Wheelbase       40
# Length          67
# dtype: int64

# %%
data['MPG_Highway'].unique()
# Out:
# array([23., 31., 29., 28., 24., 30., 26., 25., 27., 20., 22., 21., nan,
#        18., 17., 34., 37., 32., 19., 36., 13., 33., 51., 66., 38., 44.,
#        12., 16., 14., 35., 40., 43., 39., 46.])

# %% [markdown]
# ## Number of vehicles with an engine size of 2.0

# %%
#Get all vehicles with 2.0 engine
data[data['EngineSize'] == 2.0]
# Out:
#            Make                           Model    Type  Origin DriveTrain  \
# 1         Acura                  RSX Type S 2dr   Sedan    Asia      Front
# 108       Dodge                     Neon SE 4dr   Sedan     USA      Front
# 109       Dodge                    Neon SXT 4dr   Sedan     USA      Front
# 124        Ford             Focus ZX3 2dr hatch   Sedan     USA      Front
# 125        Ford                    Focus LX 4dr   Sedan     USA      Front
# 126        Ford                    Focus SE 4dr   Sedan     USA      Front
# 127        Ford                   Focus ZX5 5dr   Sedan     USA      Front
# 128        Ford                   Focus SVT 2dr   Sedan     USA      Front
# 141        Ford                       Focus ZTW   Wagon     USA      Front
# 152       Honda      Insight 2dr (gas/electric)  Hybrid    Asia      Front
# 163       Honda              Civic Si 2dr hatch   Sedan    Asia      Front
# ...

# %%
#Get how many rows from fitlered dataframe to get count
engine2_0_count = data[data['EngineSize'] == 2.0].count(axis='rows')

# %%
# Count of 2.0 Engine
engine2_0_count
# Out:
# Make           30
# Model          30
# Type           30
# Origin         30
# DriveTrain     30
# MSRP           30
# Invoice        30
# EngineSize     30
# Cylinders      30
# Horsepower     30
# MPG_City       30
# MPG_Highway    30
# Weight         30
# Wheelbase      30
# Length         30
# dtype: int64

# %% [markdown]
# ## Get Number of Vehicles with a Wheelbase of exactly 95

# %%
#Filter table to get vehicles with a wheelbse of 95
data[data['Wheelbase'] == 95]
# Out:
#               Make                           Model    Type  Origin DriveTrain  \
# 21            Audi  TT 1.8 convertible 2dr (coupe)  Sports  Europe      Front
# 105       Chrysler                   Crossfire 2dr  Sports     USA       Rear
# 152          Honda      Insight 2dr (gas/electric)  Hybrid    Asia      Front
# 168          Honda           S2000 convertible 2dr  Sports    Asia       Rear
# 210            Kia                  Rio 4dr manual   Sedan    Asia      Front
# 211            Kia                    Rio 4dr auto   Sedan    Asia      Front
# 218            Kia                       Rio Cinco   Wagon    Asia      Front
# 276  Mercedes-Benz          SLK230 convertible 2dr  Sports  Europe       Rear
# 277  Mercedes-Benz                   SLK32 AMG 2dr  Sports  Europe       Rear
# 339        Porsche         Boxster convertible 2dr  Sports  Europe       Rear
# 340        Porsche       Boxster S convertible 2dr  Sports  Europe       Rear
#
# ...

# %%
wheel_base_95_count = data[data['Wheelbase'] == 95].count(axis='rows')

# %%
# Count of wheelbase of exactly 95
wheel_base_95_count
# Out:
# Make           11
# Model          11
# Type           11
# Origin         11
# DriveTrain     11
# MSRP           11
# Invoice        11
# EngineSize     11
# Cylinders      11
# Horsepower     11
# MPG_City       11
# MPG_Highway    11
# Weight         11
# Wheelbase      11
# Length         11
# dtype: int64

# %% [markdown]
# ## Display number of null values in data

# %%
null_values = data.isnull().sum()
null_values
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
## Display rows with null values
null_rows = data[data.isnull().any(axis=1)]
null_rows
# Out:
#       Make               Model    Type Origin DriveTrain      MSRP   Invoice  \
# 30     NaN                 NaN     NaN    NaN        NaN       NaN       NaN
# 39     NaN                 NaN     NaN    NaN        NaN       NaN       NaN
# 161    NaN                 NaN     NaN    NaN        NaN       NaN       NaN
# 173    NaN                 NaN     NaN    NaN        NaN       NaN       NaN
# 251  Mazda  RX-8 4dr automatic  Sports   Asia       Rear  $25,700   $23,794
# 252  Mazda     RX-8 4dr manual  Sports   Asia       Rear  $27,200   $25,179
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 30          NaN        NaN         NaN       NaN          NaN     NaN
# 39          NaN        NaN         NaN       NaN          NaN     NaN
# 161         NaN        NaN         NaN       NaN          NaN     NaN
# 173         NaN        NaN         NaN       NaN          NaN     NaN
# 251         1.3        NaN       197.0      18.0         25.0  3053.0
# ...

# %%
# Verify: Get total count of rows
len(data.index)
# Out:
# 432

# %%
# Verify: Get total count of null rows
len(null_rows.index)
# Out:
# 6

# %%
# Verify: SUbtract total count of rows from total count of null rows
len(data.index) - len(null_rows.index)
# Out:
# 426

# %% [markdown]
# ## Change column 'Cylinders' to 'Engine Cylinders' for clarity

# %%
data.rename(columns={'Cylinders': 'Engine Cylinders'}, inplace=True)

# %%
# Verify name change of column
data
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Engine Cylinders  Horsepower  MPG_City  \
# ...

# %%
## Change Engine Cylinders column type from float to int
data['Engine Cylinders'] = data['Engine Cylinders'].fillna(0).astype(int)

# %%
## Verify change of Engine Cylinders column type
data
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Engine Cylinders  Horsepower  MPG_City  \
# ...

# %% [markdown]
# ## Get the mean of MPG_Highway

# %%
data.MPG_City.mean()
# Out:
# 20.060747663551403

# %% [markdown]
# ## Get the variance of Weight

# %%
data.Weight.var()
# Out:
# 576055.520059533

# %% [markdown]
# ## Get standard deviation of Horsepower

# %%
data.Horsepower.std()
# Out:
# 71.83603158369073

# %% [markdown]
# ## Get all instances that 'Front' Drive Train is recorded

# %%
data.head(5)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Engine Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5                 6       265.0      17.0         23.0  4451.0
# 1         2.0                 4       200.0      24.0         31.0  2778.0
# 2         2.4                 4       200.0      22.0         29.0  3230.0
# 3         3.2                 6       270.0      20.0         28.0  3575.0
# 4         3.5                 6       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# ...

# %%
#Remove null values and filter values by checking if string contains 'Front'
front_drivetrain = data.dropna()[data['DriveTrain'].dropna().str.contains('Front')]

# %%
front_drivetrain
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front  $46,100
# ..     ...                      ...    ...     ...        ...       ...
# 425  Volvo              S80 2.9 4dr  Sedan  Europe      Front  $37,730
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
#
#       Invoice  EngineSize  Engine Cylinders  Horsepower  MPG_City  \
# ...

# %%
front_drivetrain.tail(50)
# Out:
#            Make                           Model    Type  Origin DriveTrain  \
# 355      Saturn                          L300 2   Wagon     USA      Front
# 356       Scion                    xA 4dr hatch   Sedan    Asia      Front
# 357       Scion                              xB   Wagon    Asia      Front
# 369      Suzuki                         XL-7 EX     SUV    Asia      Front
# 371      Suzuki                      Aeno S 4dr   Sedan    Asia      Front
# 372      Suzuki                    Aerio LX 4dr   Sedan    Asia      Front
# 373      Suzuki                   Forenza S 4dr   Sedan    Asia      Front
# 374      Suzuki                  Forenza EX 4dr   Sedan    Asia      Front
# 375      Suzuki                   Verona LX 4dr   Sedan    Asia      Front
# 377      Toyota        Prius 4dr (gas/electric)  Hybrid    Asia      Front
# 379      Toyota                  4Runner SR5 V6     SUV    Asia      Front
# ...

# %%
data.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
#
#    EngineSize  Engine Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5                 6       265.0      17.0         23.0  4451.0
# 1         2.0                 4       200.0      24.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0

# %% [markdown]
# ## Get all Toyotas with an EngineSize greater than 2.5 and has Front DriveTrain

# %%
data[(data['EngineSize'] > 2.5) & (data['DriveTrain'] == 'Front') & (data['Make'] == 'Toyota')]
# Out:
#        Make                    Model   Type Origin DriveTrain      MSRP  \
# 379  Toyota           4Runner SR5 V6    SUV   Asia      Front  $27,710
# 390  Toyota          Camry LE V6 4dr  Sedan   Asia      Front  $22,775
# 392  Toyota   Camry Solara SE V6 2dr  Sedan   Asia      Front  $21,965
# 393  Toyota            Avalon XL 4dr  Sedan   Asia      Front  $26,560
# 394  Toyota         Camry XLE V6 4dr  Sedan   Asia      Front  $25,920
# 395  Toyota  Camry Solara SLE V6 2dr  Sedan   Asia      Front  $26,510
# 396  Toyota           Avalon XLS 4dr  Sedan   Asia      Front  $30,920
# 397  Toyota                Sienna CE  Sedan   Asia      Front  $23,495
# 398  Toyota       Sienna XLE Limited  Sedan   Asia      Front  $28,800
#
#       Invoice  EngineSize  Engine Cylinders  Horsepower  MPG_City  \
# 379  $24,801          4.0                 6       245.0      18.0
# 390  $20,325          3.0                 6       210.0      21.0
# ...

# %% [markdown]
# ## Get the mean value of each column against MPG_City

# %%
data.groupby('MPG_City').mean()
# Out:
# /tmp/ipykernel_8077/134448508.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('MPG_City').mean()
#           EngineSize  Engine Cylinders  Horsepower  MPG_Highway       Weight  \
# MPG_City
# 10.0        6.400000          9.000000  313.000000    12.500000  6795.000000
# 12.0        5.825000          9.500000  354.750000    17.750000  4691.000000
# 13.0        5.416667          8.666667  334.583333    17.500000  5281.416667
# 14.0        4.907692          7.692308  297.384615    18.076923  4922.076923
# 15.0        4.152941          6.823529  256.941176    19.882353  4529.235294
# 16.0        4.135484          6.838710  271.870968    21.516129  4153.612903
# 17.0        4.034146          7.170732  266.219512    23.634146  3911.512195
# ...

# %% [markdown]
# ## Show min and max of each column value against MSRP

# %%
data.groupby('MSRP').min()
# Out:
#                    Make                   Model    Type  Origin DriveTrain  \
# MSRP
# $10,280             Kia          Rio 4dr manual   Sedan    Asia      Front
# $10,539         Hyundai        Accent 2dr hatch   Sedan    Asia      Front
# $10,760          Toyota         Echo 2dr manual   Sedan    Asia      Front
# $10,995          Saturn                Ion1 4dr   Sedan     USA      Front
# $11,155             Kia            Rio 4dr auto   Sedan    Asia      Front
# ...                 ...                     ...     ...     ...        ...
# $86,970   Mercedes-Benz                S500 4dr   Sedan  Europe        All
# $86,995          Jaguar     XKR convertible 2dr  Sports  Europe       Rear
# $89,765           Acura  NSX coupe 2dr manual S  Sports    Asia       Rear
# $90,520   Mercedes-Benz   SL500 convertible 2dr  Sports  Europe       Rear
# $94,820   Mercedes-Benz               CL500 2dr   Sedan  Europe       Rear
#
# ...

# %%
data.groupby('MSRP').max()
# Out:
#                    Make                   Model    Type  Origin DriveTrain  \
# MSRP
# $10,280             Kia          Rio 4dr manual   Sedan    Asia      Front
# $10,539         Hyundai        Accent 2dr hatch   Sedan    Asia      Front
# $10,760          Toyota         Echo 2dr manual   Sedan    Asia      Front
# $10,995          Saturn                Ion1 4dr   Sedan     USA      Front
# $11,155             Kia            Rio 4dr auto   Sedan    Asia      Front
# ...                 ...                     ...     ...     ...        ...
# $86,970   Mercedes-Benz                S500 4dr   Sedan  Europe        All
# $86,995          Jaguar     XKR convertible 2dr  Sports  Europe       Rear
# $89,765           Acura  NSX coupe 2dr manual S  Sports    Asia       Rear
# $90,520   Mercedes-Benz   SL500 convertible 2dr  Sports  Europe       Rear
# $94,820   Mercedes-Benz               CL500 2dr   Sedan  Europe       Rear
#
# ...
